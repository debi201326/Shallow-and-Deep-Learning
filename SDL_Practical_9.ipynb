# %% [markdown]
# <a href="https://colab.research.google.com/github/debi201326/Shallow-and-Deep-Learning/blob/main/SDL_Practical_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implementing a Long Short-Term Memory (LSTM) Network for Predicting House Prices using Size, Location, Age

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
file_path = '/content/house_price.csv'
print("First few rows:")
print(data.head())
# Out:
# First few rows:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
label_enc = LabelEncoder()
data['Location'] = label_enc.fit_transform(data['Location'])

# %%
data = data.dropna()

data['Area'] = pd.to_numeric(data['Area'], errors='coerce')
data['YearBuilt'] = pd.to_numeric(data['YearBuilt'], errors='coerce')
data['Price'] = pd.to_numeric(data['Price'], errors='coerce')
data = data.dropna()

# %%
X = data[['Area', 'Location', 'YearBuilt']].values
y = data['Price'].values.reshape(-1, 1)

# %%
x_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()
X_scaled = x_scaler.fit_transform(X)
y_scaled = y_scaler.fit_transform(y)

# %%
X_scaled = X_scaled.reshape((X_scaled.shape[0], 1, X_scaled.shape[1]))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# %%
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(1, X_train.shape[2])),
    Dropout(0.2),
    LSTM(32),
    Dense(16, activation='relu'),
    Dense(1)
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 1, 64)          │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,369 (118.63 KB)
#  Trainable params: 30,369 (118.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.2155 - mae: 0.3863 - val_loss: 0.0944 - val_mae: 0.2677
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0915 - mae: 0.2592 - val_loss: 0.0899 - val_mae: 0.2617
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0882 - mae: 0.2538 - val_loss: 0.0881 - val_mae: 0.2577
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0909 - mae: 0.2609 - val_loss: 0.0877 - val_mae: 0.2583
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0830 - mae: 0.2475 - val_loss: 0.0870 - val_mae: 0.2560
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0832 - mae: 0.2457 - val_loss: 0.0873 - val_mae: 0.2576
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0825 - mae: 0.2481 - val_loss: 0.0867 - val_mae: 0.2561
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0839 - mae: 0.2485 - val_loss: 0.0870 - val_mae: 0.2548
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0812 - mae: 0.2459 - val_loss: 0.0880 - val_mae: 0.2590
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0847 - mae: 0.2501 - val_loss: 0.0866 - val_mae: 0.2560
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0835 - mae: 0.2514 - val_loss: 0.0866 - val_mae: 0.2549
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0834 - mae: 0.2496 - val_loss: 0.0873 - val_mae: 0.2576
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0824 - mae: 0.2463 - val_loss: 0.0866 - val_mae: 0.2547
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0859 - mae: 0.2546 - val_loss: 0.0869 - val_mae: 0.2545
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0832 - mae: 0.2495 - val_loss: 0.0875 - val_mae: 0.2580
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0868 - mae: 0.2551 - val_loss: 0.0871 - val_mae: 0.2572
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0826 - mae: 0.2477 - val_loss: 0.0865 - val_mae: 0.2555
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0869 - mae: 0.2563 - val_loss: 0.0870 - val_mae: 0.2569
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0869 - mae: 0.2541 - val_loss: 0.0865 - val_mae: 0.2557
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0859 - mae: 0.2541 - val_loss: 0.0877 - val_mae: 0.2584
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0841 - mae: 0.2491 - val_loss: 0.0869 - val_mae: 0.2542
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0803 - mae: 0.2432 - val_loss: 0.0864 - val_mae: 0.2551
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0840 - mae: 0.2511 - val_loss: 0.0873 - val_mae: 0.2541
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0860 - mae: 0.2554 - val_loss: 0.0866 - val_mae: 0.2559
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0841 - mae: 0.2493 - val_loss: 0.0867 - val_mae: 0.2561
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0827 - mae: 0.2497 - val_loss: 0.0883 - val_mae: 0.2594
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0869 - mae: 0.2555 - val_loss: 0.0869 - val_mae: 0.2567
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0835 - mae: 0.2489 - val_loss: 0.0864 - val_mae: 0.2552
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0860 - mae: 0.2550 - val_loss: 0.0871 - val_mae: 0.2571
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.
# Epoch 72/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0861 - mae: 0.2550 - val_loss: 0.0865 - val_mae: 0.2548
# Epoch 73/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0814 - mae: 0.2444 - val_loss: 0.0864 - val_mae: 0.2553
# Epoch 74/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0823 - mae: 0.2468 - val_loss: 0.0867 - val_mae: 0.2561
# Epoch 75/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0862 - mae: 0.2545 - val_loss: 0.0868 - val_mae: 0.2565
# Epoch 76/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0846 - mae: 0.2501 - val_loss: 0.0865 - val_mae: 0.2547
# Epoch 77/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0864 - mae: 0.2546 - val_loss: 0.0869 - val_mae: 0.2567
# Epoch 78/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0824 - mae: 0.2463 - val_loss: 0.0874 - val_mae: 0.2577
# Epoch 79/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0874 - mae: 0.2576 - val_loss: 0.0868 - val_mae: 0.2564
# Epoch 80/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0842 - mae: 0.2501 - val_loss: 0.0865 - val_mae: 0.2556
# Epoch 81/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0874 - mae: 0.2569 - val_loss: 0.0866 - val_mae: 0.2558
# Epoch 82/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0828 - mae: 0.2473 - val_loss: 0.0864 - val_mae: 0.2551
# Epoch 83/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0829 - mae: 0.2481 - val_loss: 0.0865 - val_mae: 0.2549
# Epoch 84/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0856 - mae: 0.2526 - val_loss: 0.0865 - val_mae: 0.2552
# Epoch 85/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0846 - mae: 0.2521 - val_loss: 0.0867 - val_mae: 0.2561
# Epoch 86/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0862 - mae: 0.2537 - val_loss: 0.0865 - val_mae: 0.2549
# Epoch 87/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0844 - mae: 0.2486 - val_loss: 0.0865 - val_mae: 0.2550
# Epoch 88/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0857 - mae: 0.2543 - val_loss: 0.0866 - val_mae: 0.2559
# Epoch 89/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0829 - mae: 0.2472 - val_loss: 0.0866 - val_mae: 0.2559
# Epoch 90/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0874 - mae: 0.2561 - val_loss: 0.0865 - val_mae: 0.2550
# Epoch 91/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0868 - mae: 0.2551 - val_loss: 0.0869 - val_mae: 0.2545
# Epoch 92/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0838 - mae: 0.2492 - val_loss: 0.0866 - val_mae: 0.2557
# Epoch 93/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0852 - mae: 0.2521 - val_loss: 0.0865 - val_mae: 0.2551
# Epoch 94/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0864 - mae: 0.2546 - val_loss: 0.0868 - val_mae: 0.2565
# Epoch 95/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0846 - mae: 0.2518 - val_loss: 0.0865 - val_mae: 0.2551
# Epoch 96/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0850 - mae: 0.2520 - val_loss: 0.0873 - val_mae: 0.2575
# Epoch 97/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0845 - mae: 0.2503 - val_loss: 0.0866 - val_mae: 0.2559
# Epoch 98/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0835 - mae: 0.2503 - val_loss: 0.0874 - val_mae: 0.2578
# Epoch 99/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0821 - mae: 0.2481 - val_loss: 0.0872 - val_mae: 0.2545
# Epoch 100/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0839 - mae: 0.2483 - val_loss: 0.0866 - val_mae: 0.2559

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Training & Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.show()

# %%
loss, mae = model.evaluate(X_test, y_test)
print(f"Test MAE: {mae * 100000:.2f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0835 - mae: 0.2506
# Test MAE: 25586.16

# %%
y_pred = model.predict(X_test)
y_pred_rescaled = y_scaler.inverse_transform(y_pred)
y_test_rescaled = y_scaler.inverse_transform(y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test_rescaled.flatten(), y=y_pred_rescaled.flatten(), alpha=0.7)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted House Prices")
plt.show()

# %%
print("\n--- House Price Prediction ---")
size = float(input("Enter house size (sq ft): "))
location = input("Enter location (same as in dataset): ")
age = float(input("Enter house age (years): "))

loc_encoded = label_enc.transform([location])[0]
# Out:
# --- House Price Prediction ---
# Enter house size (sq ft): 1256
# Enter location (same as in dataset): Urban
# Enter house age (years): 1991

# %%
user_input = np.array([[size, loc_encoded, age]])
user_input_scaled = x_scaler.transform(user_input)
user_input_scaled = user_input_scaled.reshape((1, 1, 3))

pred_price = model.predict(user_input_scaled)
predicted_price = y_scaler.inverse_transform(pred_price)

print(f"\nPredicted House Price: ₹{predicted_price[0][0]:,.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#
# Predicted House Price: ₹544,140.56
